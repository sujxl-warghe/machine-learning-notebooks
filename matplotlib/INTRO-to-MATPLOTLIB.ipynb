# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot();
plt.show()

# %%
plt.plot();
plt.show()

# %%
plt.plot([1, 2, 3, 4],[40, 3, 20, 1]);
plt.show()

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 1st method

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %% [markdown]
# ### 2nd Method

# %%
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]);
type(fig), type(ax)
plt.show()
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [67, 2, 98, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig = plt.figure
fig, ax = plt.subplots(figsize=(10, 10)) # (width, height)

# 3. plot the data
ax.plot(x, y)

# 4. Customize plot
ax.set(title = "Simple-Plot",
      xlabel = "x-axis",
      ylabel = "y-axis")
plt.show()
# 5. Save & show (you save the whole figure)
fig.savefig("Pictures")

# %%
plt.show()

# %% [markdown]
# ## Making figures with Numpy array

# %%
import numpy as np

# %% [markdown]
# #### np.linspace(start, stop, num)

# %%
# Create some data
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# plot the data
fig, ax = plt.subplots();
ax.plot(x, x**2);
plt.show()

# %% [markdown]
# ## Making figure with Numpy arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Hitogram
# * Subplots

# %% [markdown]
# ## Line Plot

# %%
x = np.linspace(1, 9, 100)
x
# Out:
# array([1.        , 1.08080808, 1.16161616, 1.24242424, 1.32323232,
#        1.4040404 , 1.48484848, 1.56565657, 1.64646465, 1.72727273,
#        1.80808081, 1.88888889, 1.96969697, 2.05050505, 2.13131313,
#        2.21212121, 2.29292929, 2.37373737, 2.45454545, 2.53535354,
#        2.61616162, 2.6969697 , 2.77777778, 2.85858586, 2.93939394,
#        3.02020202, 3.1010101 , 3.18181818, 3.26262626, 3.34343434,
#        3.42424242, 3.50505051, 3.58585859, 3.66666667, 3.74747475,
#        3.82828283, 3.90909091, 3.98989899, 4.07070707, 4.15151515,
#        4.23232323, 4.31313131, 4.39393939, 4.47474747, 4.55555556,
#        4.63636364, 4.71717172, 4.7979798 , 4.87878788, 4.95959596,
#        5.04040404, 5.12121212, 5.2020202 , 5.28282828, 5.36363636,
#        5.44444444, 5.52525253, 5.60606061, 5.68686869, 5.76767677,
#        5.84848485, 5.92929293, 6.01010101, 6.09090909, 6.17171717,
#        6.25252525, 6.33333333, 6.41414141, 6.49494949, 6.57575758,
# ...

# %%
fig = plt.figure()
fig, s= plt.subplots()
s.plot(x**3, x)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
fig = plt.figure()
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))
plt.show()

# %%
fig = plt.figure()
fig, ax = plt.subplots()
ax.scatter(np.sin(x), np.cos(x))
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
nut_butter_prices = {"Almond Butter" : 10,
                     "Peanut Butter" : 8,
                     "Cashew Butter" : 12}

# %%
fig = plt.figure();
fig, ax = plt.subplots();
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title = "Sujal's Butter Store",
       xlabel = "Types of Butter",
       ylabel = "Prices ($)");
plt.show();

# %% [markdown]
# ## Horizontal Bar Plot

# %%
fig = plt.figure();
fig, ax = plt.subplots();
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
ax.set(title = "Sujal's  Butter Shop",
      xlabel = "Prices ($)")
plt.show()

# %% [markdown]
# ## Histogram()

# %%
x2 = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x2);
plt.show()

# %% [markdown]
# ### Two options of subplots

# %%
# Subplot option 1
fig,  ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10, 7));

# Plot to each different axis
ax1.plot(x, x**2)
ax2.scatter(np.sin(np.random.random(10)), np.cos(np.random.rand(10)))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))

ax1.set(title = "Line Plot")
ax2.set(title = "Scatter Plot")
ax3.set(title = "Bar Plot")
ax4.set(title = "Histogram")
plt.show()

# %%
# subplot option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10, 5));

# plot to each different index

ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.rand(10), np.random.rand(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));
plt.show()

# %% [markdown]
# ### cumsum()

# %%
import pandas as pd
df = pd.DataFrame({'Sales' : [100, 200, 150, 300]})   # cumulative sum

df['Cumulative Sum'] = df['Sales'].cumsum()
df
# Out:
#    Sales  Cumulative Sum
# 0    100             100
# 1    200             300
# 2    150             450
# 3    300             750

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2025", periods=1000));
ts = ts.cumsum();
ts.plot()
plt.show()

# %%
import pandas as pd
car_sales = pd.read_csv("7.1 car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].replace(r'[$]' , '', regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4   4,000.00
# 1   Honda    Red          87899      4   5,000.00
# 2  Toyota   Blue          32549      3   7,000.00
# 3     BMW  Black          11179      5  22,000.00
# 4  Nissan  White         213095      4   3,500.00
# 5  Toyota  Green          99213      4   4,500.00
# 6   Honda   Blue          45698      4   7,500.00
# 7   Honda   Blue          54738      4   7,000.00
# 8  Toyota  White          60000      4   6,250.00
# 9  Nissan  White          31600      4   9,700.00

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales["Price"] = car_sales["Price"].replace(r'[,\.]' , '' ,regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sales Date"] = pd.date_range("1/1/2020", periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  \
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10
#
#                                  Total Sales
# 0                                       4000
# 1                                   40005000
# 2                               400050007000
# 3                          40005000700022000
# 4                      400050007000220003500
# 5                  4000500070002200035004500
# ...

# %%
print(type(car_sales["Price"][0]))
# Out:
# <class 'str'>

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Sales Date", y="Total Sales");
plt.show();

# %%
# Reassigning price column to int
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot scatter plot with price column as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind="bar");

plt.show()

# %%
fig = plt.figure();
fig, ax = plt.subplots();
ax.plot(car_sales["Sales Date"], car_sales["Total Sales"]);
plt.show()

# %%
x = np.random.rand(10,4)
x
# Turn it into dataframe
df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.718986  0.956926  0.522505  0.178800
# 1  0.317648  0.084157  0.135289  0.795250
# 2  0.432776  0.595860  0.958599  0.541688
# 3  0.827990  0.775638  0.345707  0.695050
# 4  0.326764  0.838292  0.921089  0.318504
# 5  0.679131  0.715563  0.955583  0.500223
# 6  0.474887  0.020765  0.331988  0.345364
# 7  0.279669  0.343932  0.560566  0.747554
# 8  0.400379  0.561020  0.215142  0.067773
# 9  0.663115  0.062370  0.779396  0.034629

# %%
df.plot.bar();

# %%
plt.show()

# %%
df.plot(kind="bar");
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(kind = "bar");
plt.show()

# %%
car_sales.plot(x = 'Make', y = 'Odometer (KM)' , kind = 'bar', color = 'red')
plt.show()

# %%
# histogram
car_sales['Odometer (KM)'].plot.hist()
plt.show()

# %%
car_sales["Odometer (KM)"].plot.hist(bins = 30);
plt.show()

# %%
car_sales["Odometer (KM)"].plot.hist(bins = 10)
plt.show()

# %% [markdown]
# ### Working on Heart disease Dataset

# %%
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Creat a histogram
heart_disease['age'].plot.hist()
plt.show()

# %%
heart_disease.plot.bar()
plt.show()

# %%
heart_disease['age'].plot.hist(bins=10)
plt.show()

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots = True)
plt.show()

# %% [markdown]
# ### Which one should you use? (pyplot vs matpltlib OO method? )
# * When plotting something quickly, okay to use the pyplot method
# * When plotting something more advanced, use the OO method

# %%
over_50 = heart_disease[heart_disease['age'] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
len(over_50)
# Out:
# 208

# %%
# pyplot method
over_50.plot(kind = 'scatter',
            x = 'age',
            y = 'chol',
            c = 'target',
            figsize = (10, 6));
plt.show()

# %%
# OO method
fix, ax = plt.subplots(figsize = (10, 6))
over_50.plot(kind = 'scatter',
            x = 'age',
            y = 'chol',
            c = 'target',
            ax=ax)

# axis limit
# ax.set_xlim([45, 100])

plt.show()

# %%
# OO method from scratch (object oriented)
fig, ax = plt.subplots(figsize=(10, 6));

# Plot the data
scatter = ax.scatter(x = over_50['age'],
                    y = over_50['chol'],
                    c=over_50['target']);

ax.set(title = 'Heart Disease and Cholestrol Levels',
      xlabel = 'Age',
      ylabel = 'Cholestrol')

# Add a legend
ax.legend(*scatter.legend_elements(), title = "Target")

# add a horizontal line
ax.axhline(over_50['chol'].mean(),
          linestyle = '--')

plt.show()

# %%
# Subplots
fig, (ax0, ax1) = plt.subplots(nrows = 2,
                              ncols = 1,
                              figsize = (10, 10))
plt.show()

# %%
# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows = 2,
                              ncols = 1,
                              figsize = (10, 10));
# Add data to ax0
scatter = ax0.scatter(x = over_50['age'],
                     y = over_50['chol'],
                     c = over_50['target']);

# customize ax0
ax0.set(title = 'Heart Disease and Cholesterol Levels',
       xlabel = 'Age',
       ylabel = 'Cholestrol');

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title = 'Target');

# Add a meanline
ax0.axhline(y = over_50['chol'].mean(),
           linestyle = '--');


# add data to ax1
scatter = ax1.scatter(x = over_50['age'],
                      y = over_50['thalach'],
                      c = over_50['target'])

# Customize ax1
ax1.set(title = 'Heart Disease and Max Heart Rate',
        xlabel = 'Age',
        ylabel = 'Max Heart Rate')

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title = 'Target')

# Add a meanline
ax1.axhline(y = over_50['thalach'].mean(),
           linestyle = '--')

plt.show()

# %%
# Here we share the x-axis 
# in this x-axis is common

# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows = 2,
                              ncols = 1,
                              figsize = (10, 10),
                              sharex = True );       #>>>x-common
# Add data to ax0
scatter = ax0.scatter(x = over_50['age'],
                     y = over_50['chol'],
                     c = over_50['target']);

# customize ax0
ax0.set(title = 'Heart Disease and Cholesterol Levels',
       ylabel = 'Cholestrol');

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title = 'Target');

# Add a meanline
ax0.axhline(y = over_50['chol'].mean(),
           linestyle = '--');


# add data to ax1
scatter = ax1.scatter(x = over_50['age'],
                      y = over_50['thalach'],
                      c = over_50['target'])

# Customize ax1
ax1.set(title = 'Heart Disease and Max Heart Rate',
        xlabel = 'Age',
        ylabel = 'Max Heart Rate')

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title = 'Target')

# Add a meanline
ax1.axhline(y = over_50['thalach'].mean(),
           linestyle = '--');

# Add a title to the figure
fig.suptitle('Heart Disease Analysis', fontsize = 16 , fontweight = 'bold')

plt.show()

# %% [markdown]
# ## Customizing matplotlib plots and getting stylish

# %%
# see the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500

# %%
car_sales['Price'].plot()  #plt.style.use('default') it is default style of matplotlib
plt.show()

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
car_sales['Price'].plot()
plt.show()

# %%
plt.style.use('seaborn-v0_8')

# %%
car_sales['Price'].plot()
plt.show()

# %%
car_sales.plot(x = 'Odometer (KM)', y = 'Price', kind = 'scatter')
plt.show()

# %%
plt.style.use('ggplot')
car_sales['Price'].plot()
plt.show()

# %%
x = np.random.randn(10, 4)
x
# Out:
# array([[-0.80379474,  0.27150891, -1.60557472,  0.00577684],
#        [-0.81768864, -1.65404994, -1.06727171, -0.51630641],
#        [-0.33109525,  0.09723466,  1.31632976, -0.12534621],
#        [ 0.35382034,  1.46867092, -0.82744598,  0.39710439],
#        [-0.62351505,  1.78628015, -1.21115742, -1.08190834],
#        [-1.72349168,  0.33108724,  0.97095871,  0.75647021],
#        [ 0.87820573, -0.28421395, -0.97332979, -0.26970698],
#        [ 0.60581989, -0.87678415,  0.46021853,  0.46724289],
#        [-0.56612632,  1.76274767,  0.15088576,  0.79954149],
#        [ 1.35159973,  1.50556808, -0.75006043, -0.26882004]])

# %%
df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.803795  0.271509 -1.605575  0.005777
# 1 -0.817689 -1.654050 -1.067272 -0.516306
# 2 -0.331095  0.097235  1.316330 -0.125346
# 3  0.353820  1.468671 -0.827446  0.397104
# 4 -0.623515  1.786280 -1.211157 -1.081908
# 5 -1.723492  0.331087  0.970959  0.756470
# 6  0.878206 -0.284214 -0.973330 -0.269707
# 7  0.605820 -0.876784  0.460219  0.467243
# 8 -0.566126  1.762748  0.150886  0.799541
# 9  1.351600  1.505568 -0.750060 -0.268820

# %%
ax = df.plot(kind = 'bar')

# Add soe labels and title
ax.set(title = 'Random Number Bar Graphfrom DataFrame',
      xlabel = 'Row Number',
      ylabel = 'Random Number')
ax.set()
plt.show()

# %%
# set the style 
plt.style.use('seaborn-v0_8-whitegrid')

# OO method from scratch (object oriented)
fig, ax = plt.subplots(figsize=(10, 6));

# Plot the data
scatter = ax.scatter(x = over_50['age'],
                    y = over_50['chol'],
                    c=over_50['target'],
                    cmap = 'winter');

ax.set(title = 'Heart Disease and Cholestrol Levels',
      xlabel = 'Age',
      ylabel = 'Cholestrol')

# Add a legend
ax.legend(*scatter.legend_elements(), title = "Target")

# add a horizontal line
ax.axhline(over_50['chol'].mean(),
          linestyle = '--')

plt.show()

# %% [markdown]
# ### This plot shows some information about the heart disease dataset.....

# %%
# Here we share the x-axis 
# in this x-axis is common

# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows = 2,
                              ncols = 1,
                              figsize = (10, 10),
                              sharex = True );       #>>>x-common
# Add data to ax0
scatter = ax0.scatter(x = over_50['age'],
                     y = over_50['chol'],
                     c = over_50['target'],
                     cmap = 'winter');

# customize ax0
ax0.set(title = 'Heart Disease and Cholesterol Levels',
       ylabel = 'Cholestrol');

# Chaange the x-axis limit
ax0.set_xlim([50, 80])

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title = 'Target');

# Add a meanline
ax0.axhline(y = over_50['chol'].mean(),
           linestyle = '--');


# add data to ax1
scatter = ax1.scatter(x = over_50['age'],
                      y = over_50['thalach'],
                      c = over_50['target'],
                     cmap = 'winter')

# Customize ax1
ax1.set(title = 'Heart Disease and Max Heart Rate',
        xlabel = 'Age',
        ylabel = 'Max Heart Rate')

# Change ax1 x-axis limits
ax1.set_xlim([50, 80])
ax1.set_ylim([50, 200])

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title = 'Target')

# Add a meanline
ax1.axhline(y = over_50['thalach'].mean(),
           linestyle = '--');

# Add a title to the figure
fig.suptitle('Heart Disease Analysis', fontsize = 16 , fontweight = 'bold')

plt.show()

# %%
fig.savefig("heaart-disease-analysis.png")
